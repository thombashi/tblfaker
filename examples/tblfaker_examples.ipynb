# %%
from tblfaker import TableFaker

# %%
# Basic usage: get outputs as tuples

faker = TableFaker()

print("[1]")
for row in faker.generate(["name", "address"], rows=4).as_tuple():
    print(row)

print("\n[2]")
for row in faker.generate(["name", "address"], rows=4).as_tuple():
    print(row)
# Out:
# [1]
# Row(name='Lisa Dickson', address='710 Tonya Mission Suite 358\nPort Michael, GA 72837')
# Row(name='Margaret Murray', address='72469 Johns Course\nBarreraside, FL 39637')
# Row(name='Alexandra Wallace', address='92315 David Islands Suite 961\nBrucemouth, RI 77412')
# Row(name='Darrell Reynolds', address='090 Frank Radial\nNorth Emilyburgh, SC 34259')
#
# [2]
# Row(name='Renee West', address='7222 Evelyn Meadow\nSouth Erinburgh, AR 75330')
# Row(name='Maurice Moreno', address='2047 Smith Rapids Suite 231\nPetersonton, OK 06090')
# Row(name='Bethany Dudley', address='180 Nathan Hill\nWest Jessica, OR 85988')
# Row(name='Michael Lane', address='1828 Scott Haven Suite 791\nPort Casey, PA 90700')

# %%
# Basic usage: using a seed to get stable outputs

seed = 1

print("[1]")
faker = TableFaker(seed=seed)
for row in faker.generate(["name", "address"], rows=4).as_tuple():
    print(row)

print("\n[2]")
faker = TableFaker(seed=seed)
for row in faker.generate(["name", "address"], rows=4).as_tuple():
    print(row)
# Out:
# [1]
# Row(name='Ryan Gallagher', address='6317 Mary Light\nSmithview, HI 13900')
# Row(name='Amanda Johnson', address='3608 Samuel Mews Apt. 337\nHousebury, WA 13608')
# Row(name='Willie Heath', address='868 Santiago Grove\nNicolehaven, NJ 05026')
# Row(name='Dr. Jared Ortega', address='517 Rodriguez Divide Suite 570\nWest Melinda, NH 85325')
#
# [2]
# Row(name='Ryan Gallagher', address='6317 Mary Light\nSmithview, HI 13900')
# Row(name='Amanda Johnson', address='3608 Samuel Mews Apt. 337\nHousebury, WA 13608')
# Row(name='Willie Heath', address='868 Santiago Grove\nNicolehaven, NJ 05026')
# Row(name='Dr. Jared Ortega', address='517 Rodriguez Divide Suite 570\nWest Melinda, NH 85325')

# %%
# Change locale

faker = TableFaker(locale="ja_JP")

for row in faker.generate(["name", "address"], rows=4).as_tuple():
    print(row)
# Out:
# Row(name='高橋 零', address='京都府横浜市磯子区山中新田33丁目12番19号 アーバン鳥越906')
# Row(name='宮沢 裕美子', address='高知県三鷹市麹町28丁目2番16号 シャルム猿楽町867')
# Row(name='佐藤 明美', address='香川県新宿区東神田15丁目21番6号 皇居外苑ハイツ840')
# Row(name='野村 あすか', address='北海道新島村湯宮8丁目26番20号')

# %%
# Get outputs as JSON

import json

faker = TableFaker(seed=1)

print(json.dumps(faker.generate(["name", "address"], rows=2, table_name="dict").as_dict(), indent=4))
# Out:
# {
#     "dict": [
#         {
#             "name": "Ryan Gallagher",
#             "address": "6317 Mary Light\nSmithview, HI 13900"
#         },
#         {
#             "name": "Amanda Johnson",
#             "address": "3608 Samuel Mews Apt. 337\nHousebury, WA 13608"
#         }
#     ]
# }

# %%
# List providers

from tblfaker import get_providers

for provider in sorted(get_providers()):
    print(provider)
# Out:
# address
# am_pm
# android_platform_token
# ascii_company_email
# ascii_email
# ascii_free_email
# ascii_safe_email
# bank_country
# bban
# binary
# boolean
# bothify
# bs
# building_number
# catch_phrase
# century
# chrome
# city
# city_prefix
# city_suffix
# color
# color_name
# company
# company_email
# company_suffix
# coordinate
# country
# country_calling_code
# country_code
# credit_card_expire
# credit_card_full
# credit_card_number
# credit_card_provider
# credit_card_security_code
# cryptocurrency
# cryptocurrency_code
# cryptocurrency_name
# csv
# currency
# currency_code
# currency_name
# currency_symbol
# date
# date_between
# date_between_dates
# date_object
# date_of_birth
# date_this_century
# date_this_decade
# date_this_month
# date_this_year
# date_time
# date_time_ad
# date_time_between
# date_time_between_dates
# date_time_this_century
# date_time_this_decade
# date_time_this_month
# date_time_this_year
# day_of_month
# day_of_week
# dga
# domain_name
# domain_word
# dsv
# ean
# ean13
# ean8
# ein
# email
# file_extension
# file_name
# file_path
# firefox
# first_name
# first_name_female
# first_name_male
# first_name_nonbinary
# fixed_width
# free_email
# free_email_domain
# future_date
# future_datetime
# hex_color
# hexify
# hostname
# http_method
# iban
# image_url
# internet_explorer
# invalid_ssn
# ios_platform_token
# ipv4
# ipv4_network_class
# ipv4_private
# ipv4_public
# ipv6
# isbn10
# isbn13
# iso8601
# itin
# job
# json
# language_code
# language_name
# last_name
# last_name_female
# last_name_male
# last_name_nonbinary
# latitude
# latlng
# lexify
# license_plate
# linux_platform_token
# linux_processor
# local_latlng
# locale
# localized_ean
# localized_ean13
# localized_ean8
# location_on_land
# longitude
# mac_address
# mac_platform_token
# mac_processor
# md5
# military_apo
# military_dpo
# military_ship
# military_state
# mime_type
# month
# month_name
# msisdn
# name
# name_female
# name_male
# name_nonbinary
# null_boolean
# numerify
# opera
# paragraph
# paragraphs
# password
# past_date
# past_datetime
# phone_number
# port_number
# postalcode
# postalcode_in_state
# postalcode_plus4
# postcode
# postcode_in_state
# prefix
# prefix_female
# prefix_male
# prefix_nonbinary
# profile
# psv
# pybool
# pydecimal
# pydict
# pyfloat
# pyint
# pyiterable
# pylist
# pyset
# pystr
# pystr_format
# pystruct
# pytimezone
# pytuple
# random_choices
# random_digit
# random_digit_not_null
# random_digit_not_null_or_empty
# random_digit_or_empty
# random_element
# random_elements
# random_int
# random_letter
# random_letters
# random_lowercase_letter
# random_number
# random_sample
# random_uppercase_letter
# randomize_nb_elements
# rgb_color
# rgb_css_color
# safari
# safe_color_name
# safe_domain_name
# safe_email
# safe_hex_color
# secondary_address
# seed_instance
# sentence
# sentences
# sha1
# sha256
# simple_profile
# slug
# ssn
# state
# state_abbr
# street_address
# street_name
# street_suffix
# suffix
# suffix_female
# suffix_male
# suffix_nonbinary
# swift
# swift11
# swift8
# tar
# text
# texts
# time
# time_delta
# time_object
# time_series
# timezone
# tld
# tsv
# unix_device
# unix_partition
# unix_time
# upc_a
# upc_e
# uri
# uri_extension
# uri_page
# uri_path
# url
# user_agent
# user_name
# uuid4
# windows_platform_token
# word
# words
# year
# zip
# zipcode
# zipcode_in_state
# zipcode_plus4

# %%
providers = get_providers() - {"zip"}
limit = 32

for provider, row in zip(providers, faker.generate(providers, rows=2).transpose().rows):
    print("{}: {}".format(
        provider,
        [value[:limit] if isinstance(value, (str, list)) else str(value)[:limit] for value in row]
    ))
# Out:
# name_nonbinary: ['Victoria Heath', 'Rhonda Vargas']
# json: ['[{"name": "Gary Griffith", "resi', '[{"name": "Mr. Joel Santos", "re']
# time_delta: ['0:00:00', '0:00:00']
# uri_extension: ['.htm', '.asp']
# random_element: ['b', 'a']
# mac_processor: ['U; PPC', 'U; Intel']
# month_name: ['September', 'April']
# uuid4: ['39455353-8cde-4e75-921e-bce6139f', '9d5e1f4d-2870-4155-977c-5ec769d4']
# credit_card_expire: ['04/30', '09/20']
# last_name_male: ['Miller', 'Rodriguez']
# random_choices: [['b', 'a'], ['a']]
# ios_platform_token: ['iPad; CPU iPad OS 4_2_1 like Mac', 'iPhone; CPU iPhone OS 9_3_6 like']
# dga: ['gimdvtiombdfilhlsges.com', 'lghkqufvqfmivhorxbxmxqsmpclrefqa']
# first_name_female: ['Alexandria', 'Linda']
# credit_card_security_code: ['161', '804']
# last_name_nonbinary: ['Mckenzie', 'Brown']
# pybool: ['False', 'False']
# text: ['Size only class late race. Seaso', 'Street agency firm against run b']
# random_elements: [['a'], ['b', 'a', 'a']]
# random_letters: [['m', 'd', 'C', 'd', 'd', 'H', 'p', 'P', 'z', 'S', 'i', 'A', 'P', 'e', 'X', 'j'], ['s', 'o', 'R', 'W', 'r', 'y', 'o', 'W', 'G', 'Q', 'C', 'H', 'N', 'v', 'V', 'l']]
# password: ['*Q2Kj_t##s', '6g*9DvdO)d']
# random_sample: [['c', 'a'], ['b', 'c', 'a']]
# location_on_land: ["('-8.05389', '-34.88111', 'Recif", "('-19.72806', '-50.19556', 'Itur"]
# pyset: ['{datetime.datetime(1972, 10, 8, ', "{Decimal('0.0'), 'duncanandre@ya"]
# city_prefix: ['South', 'North']
# internet_explorer: ['Mozilla/5.0 (compatible; MSIE 5.', 'Mozilla/5.0 (compatible; MSIE 7.']
# century: ['VIII', 'XIX']
# free_email_domain: ['yahoo.com', 'gmail.com']
# currency_name: ['Special drawing rights', 'Ugandan shilling']
# opera: ['Opera/9.36.(X11; Linux i686; am-', 'Opera/8.56.(X11; Linux i686; gv-']
# phone_number: ['(283)449-4728', '570-778-9376x7901']
# ascii_safe_email: ['robertmartinez@example.org', 'toddwallace@example.com']
# language_name: ['Turkmen', 'Spanish']
# random_digit_or_empty: ['', '6']
# name_female: ['Ashley Aguirre', 'Rebecca Simpson']
# rgb_color: ['60,6,151', '19,171,111']
# postalcode: ['88832', '69166']
# last_name: ['Juarez', 'Brown']
# pytimezone: ["tzfile('/usr/share/zoneinfo/Euro", "tzfile('/usr/share/zoneinfo/Afri"]
# date_time_this_decade: ['2020-01-30 04:45:42', '2020-04-11 16:29:25']
# coordinate: ['88.634888', '7.301302']
# date_of_birth: ['1955-07-11', '1958-11-16']
# pydecimal: ['7203789374.97', '478817651488573.0']
# longitude: ['103.679352', '55.422938']
# zipcode: ['42927', '39954']
# country_calling_code: ['+93', '+20']
# ascii_email: ['kevinross@vega.com', 'jameshowell@garcia.com']
# numerify: ['380', '816']
# paragraph: ['Reveal school rock current type ', 'Herself near performance do skin']
# msisdn: ['9665991734062', '5751742645849']
# isbn13: ['978-1-4219-0546-4', '978-0-13-655784-5']
# profile: ["{'job': 'Sports administrator', ", "{'job': 'Jewellery designer', 'c"]
# pydict: ["{'author': 'QbNJzBLUwIoFilmxNYmo", "{'society': datetime.datetime(20"]
# pystr: ['MkuqvgdpPBvqoMBagqLO', 'pDubmtTnnpFGObGAogXM']
# seed_instance: ['<faker.generator.Generator objec', '<faker.generator.Generator objec']
# slug: ['officer-source', 'nation-true-skin']
# user_agent: ['Mozilla/5.0 (Macintosh; PPC Mac ', 'Mozilla/5.0 (iPhone; CPU iPhone ']
# name_male: ['Rodney Abbott', 'Eric Hess']
# localized_ean8: ['04191537', '05090433']
# job: ['Heritage manager', 'Engineer, land']
# mime_type: ['model/x3d+xml', 'audio/vorbis']
# ipv4_private: ['10.178.150.121', '192.168.184.42']
# zipcode_in_state: ['20032', '03276']
# randomize_nb_elements: ['13', '13']
# cryptocurrency_name: ['Bitcoin Cash', 'Ethereum Classic']
# hexify: ['8d50', '610f']
# domain_word: ['richard-taylor', 'wright']
# suffix: ['PhD', 'MD']
# texts: [['Sometimes else you shake throw. Light free show record onto. Teacher research choice year situation.\nSong doctor child letter throughout heavy check. Expert hold model art quite.', 'Character rule eat me beautiful hard their. Draw recent analysis visit.\nFar tax oil son.', 'Picture science health nearly. Art while partner might bar when. Grow now staff same particularly life.\nRock source send ten. Dog attack prevent become not.'], ['Pretty send campaign prevent. Writer exist huge cover specific fear tonight science. Fill task safe party.', 'Out guy charge must public human. Line continue clearly particularly area.', 'Yard series long learn imagine. Ready agency treatment future. Want already generation type knowledge.\nModern small benefit full huge describe. Wind truth billion skin society billion hot.']]
# currency_symbol: ['₨', '₪']
# random_uppercase_letter: ['X', 'I']
# zipcode_plus4: ['61032-0572', '69578-3410']
# date_between: ['1990-09-14', '2012-12-08']
# pystr_format: ['g7-5177193C', 'W6-9327781t']
# secondary_address: ['Suite 613', 'Apt. 948']
# date_object: ['1993-04-16', '1998-02-09']
# address: ['411 Rich Square\nWest Cynthiamout', 'PSC 2492, Box 3122\nAPO AA 90721']
# ipv4_network_class: ['a', 'c']
# city_suffix: ['mouth', 'ton']
# latlng: ["(Decimal('89.965248'), Decimal('", "(Decimal('-61.730035'), Decimal("]
# first_name_nonbinary: ['Dennis', 'David']
# ipv6: ['b650:7ac8:dac:643:26cc:1afe:a51e', 'ba3d:4986:7ea7:5db8:986c:c86:3f1']
# country_code: ['BT', 'CZ']
# linux_platform_token: ['X11; Linux i686', 'X11; Linux i686']
# safe_domain_name: ['example.org', 'example.org']
# military_state: ['AE', 'AE']
# sentence: ['Industry from statement surface ', 'Statement most believe trial.']
# ein: ['91-2471746', '93-6704812']
# postcode_in_state: ['17502', '72572']
# day_of_month: ['04', '18']
# safe_color_name: ['black', 'green']
# sentences: [['Among head control tonight environmental allow see.', 'Finally break half spend factor start travel seem.', 'News more along child public weight.'], ['Actually act water civil share fund.', 'Result care occur accept federal if.', 'Moment it tough front so alone rock.']]
# sha256: ['b68cbc2c87d6c0e3ab0f7a9371f020da', 'c24d67605331c2f51f0340441a56b40f']
# suffix_male: ['PhD', 'Jr.']
# name: ['Dr. Stephen Perez DVM', 'Kristin Johnson']
# first_name: ['Amy', 'Justin']
# postcode: ['41155', '61369']
# paragraphs: [['Look air or everyone statement especially give. Author trial begin. Bag shake director deep institution such.', 'Piece during later brother our.', 'Marriage again strategy memory one until look join. Big among child floor artist security bill. Someone page front top.'], ['Recent his sort. Against spring imagine senior down.', 'Year guess paper glass answer the. Side rise interest wish describe civil. So it miss election television.', 'Debate them small apply exist effort. Sea west respond power health word. Size later exactly next finish idea.']]
# port_number: ['49536', '10165']
# credit_card_provider: ['VISA 16 digit', 'VISA 16 digit']
# safari: ['Mozilla/5.0 (Macintosh; U; Intel', 'Mozilla/5.0 (Macintosh; U; PPC M']
# ssn: ['596-61-0061', '247-64-6773']
# swift: ['MMFUGBFX', 'HAEMGB5966W']
# future_date: ['2020-09-09', '2020-09-23']
# tld: ['com', 'com']
# ean8: ['97387244', '02458779']
# pytuple: ["('ariasdouglas@hotmail.com', 'rU", "('smithcathy@gmail.com', 'kylie0"]
# word: ['cultural', 'trade']
# date_between_dates: ['2020-08-29', '2020-08-29']
# date_time_this_century: ['2010-09-28 19:47:06', '2015-07-19 14:43:25']
# linux_processor: ['i686', 'x86_64']
# state: ['Washington', 'Utah']
# date_time_between: ['1999-07-08 05:40:24', '2004-08-12 17:43:10']
# isbn10: ['0-9748190-0-X', '0-230-28638-0']
# fixed_width: ['John Bailey         15 \nEric Her', 'Ashley Price        2  \nMichael ']
# null_boolean: ['False', 'False']
# street_name: ['Jean Corner', 'Isaac Mall']
# suffix_nonbinary: ['DVM', 'DDS']
# cryptocurrency: ["('ETC', 'Ethereum Classic')", "('VTC', 'Vertcoin')"]
# hostname: ['web-15.morris-chandler.com', 'laptop-27.moore.org']
# file_name: ['professional.tiff', 'attorney.xls']
# uri_path: ['category/app', 'categories/main']
# bothify: ['66 MS', '33 Jf']
# date_time: ['2017-05-28 22:46:34', '1971-03-06 21:09:13']
# rgb_css_color: ['rgb(195,206,209)', 'rgb(55,216,54)']
# words: [['two', 'glass', 'television'], ['form', 'center', 'style']]
# prefix_nonbinary: ['Ind.', 'Misc.']
# invalid_ssn: ['043-00-0712', '925-05-9121']
# time_series: ['<generator object Provider.time_', '<generator object Provider.time_']
# url: ['https://www.hill-frazier.biz/', 'http://ward.com/']
# bban: ['RFUS35472366422513', 'CNEH07941020968629']
# building_number: ['66007', '4250']
# firefox: ['Mozilla/5.0 (iPhone; CPU iPhone ', 'Mozilla/5.0 (Windows NT 5.1; da-']
# random_digit: ['0', '6']
# locale: ['hak_TW', 'ga_IE']
# date_this_month: ['2020-08-18', '2020-08-10']
# date_time_this_year: ['2020-04-24 10:43:56', '2020-07-05 17:15:01']
# cryptocurrency_code: ['TIT', 'AUR']
# ean13: ['6530547658876', '5819344383329']
# ascii_company_email: ['patricia34@payne.com', 'awalker@estrada-smith.com']
# safe_email: ['christopherwood@example.com', 'qsteele@example.com']
# random_letter: ['m', 'm']
# prefix: ['Mr.', 'Dr.']
# upc_e: ['15136657', '16545144']
# year: ['2009', '2013']
# psv: ['"Keith Bridges"|"928 Denise Fiel', '"William Turner"|"329 James Esta']
# upc_a: ['342142280965', '324393256364']
# ean: ['1047458578292', '9051832929268']
# color_name: ['DarkViolet', 'LavenderBlush']
# file_path: ['/song/measure.xls', '/citizen/story.csv']
# month: ['02', '06']
# swift8: ['GXMCGB45', 'YDREGBI0']
# ipv4_public: ['63.18.150.86', '214.68.49.16']
# lexify: ['TiaS', 'JsxH']
# date_this_century: ['2016-04-02', '2006-04-29']
# bs: ['monetize holistic paradigms', 'target world-class experiences']
# local_latlng: ["('47.4943', '-122.24092', 'Bryn ", "('39.71734', '-74.96933', 'Sickl"]
# day_of_week: ['Friday', 'Thursday']
# last_name_female: ['Maldonado', 'Young']
# prefix_female: ['Mrs.', 'Mrs.']
# sha1: ['df764854219d470d2254cae59b137576', '93806d6440d5a1e451789b46a830359e']
# boolean: ['True', 'False']
# catch_phrase: ['Distributed object-oriented matr', 'Grass-roots homogeneous customer']
# bank_country: ['GB', 'GB']
# chrome: ['Mozilla/5.0 (Linux; Android 5.0.', 'Mozilla/5.0 (X11; Linux i686) Ap']
# image_url: ['https://placekitten.com/2/245', 'https://placekitten.com/438/991']
# pyiterable: ["{'sFhAEBCoMsBpNITbUScI', datetim", "('https://parks-booth.com/app/in"]
# state_abbr: ['NJ', 'ID']
# unix_device: ['/dev/vdh', '/dev/sdh']
# company_suffix: ['Ltd', 'LLC']
# city: ['Goodmanside', 'Smithport']
# currency: ["('DJF', 'Djiboutian franc')", "('TOP', 'Tongan paʻanga')"]
# simple_profile: ["{'username': 'cindydorsey', 'nam", "{'username': 'smithstephanie', '"]
# csv: ['"Miranda Ross","188 Michelle Hav', '"Jon Mason","649 Steven Drive Su']
# date: ['1977-04-10', '1991-01-25']
# file_extension: ['mp3', 'wav']
# mac_platform_token: ['Macintosh; PPC Mac OS X 10_9_3', 'Macintosh; Intel Mac OS X 10_5_4']
# free_email: ['jamesjohnson@gmail.com', 'amber72@gmail.com']
# street_suffix: ['Plains', 'Square']
# localized_ean13: ['0881804323980', '0594833726850']
# binary: ["b'\\x06\\xa8W<\\xa4\\xb2\\x13\\x89\\x82", "b'\\x99\\x9bh\\xe8T\\x9aL\\xff\\xd11\\x"]
# mac_address: ['01:7e:b1:f2:97:99', '53:6f:25:60:df:42']
# date_time_between_dates: ['2020-08-29 00:29:09', '2020-08-29 00:29:11']
# safe_hex_color: ['#dddd00', '#ee2200']
# future_datetime: ['2020-09-07 02:13:22', '2020-09-23 03:04:31']
# date_time_ad: ['1565-02-06 10:01:33', '0254-05-19 01:09:07']
# military_apo: ['PSC 2946, Box 9894', 'PSC 5461, Box 5885']
# ascii_free_email: ['heatherreed@gmail.com', 'andrewmorris@gmail.com']
# pyfloat: ['188628.4742', '-9.32043687001']
# military_ship: ['USNV', 'USNS']
# currency_code: ['SYP', 'AUD']
# domain_name: ['galvan.com', 'ford.biz']
# timezone: ['Europe/Berlin', 'Africa/Maputo']
# date_time_this_month: ['2020-08-16 18:13:59', '2020-08-24 00:57:00']
# first_name_male: ['Kenneth', 'Jon']
# tsv: ['"John Simon Jr."\t"Unit 2457 Box ', '"Adrian Williams"\t"053 Wright Pi']
# tar: ["b'QmjvYYXwzFGVBiKoeoMm1\\x00\\x00\\", "b'WMXbYBteuulctAzzEeSW1\\x00\\x00\\"]
# am_pm: ['PM', 'AM']
# time_object: ['21:20:35', '19:48:12']
# past_datetime: ['2020-08-27 04:02:07', '2020-08-07 03:41:28']
# time: ['11:54:04', '00:56:43']
# credit_card_full: ['Mastercard\nCarla Lopez\n526706151', 'JCB 15 digit\nCindy Martin\n213160']
# unix_time: ['242505592', '937942080']
# prefix_male: ['Mr.', 'Mr.']
# postalcode_plus4: ['37240-8652', '65490-1737']
# license_plate: ['489F2', 'LJV 750']
# date_this_decade: ['2020-06-25', '2020-03-20']
# unix_partition: ['/dev/sdj7', '/dev/sdu5']
# itin: ['955-92-3890', '977-94-6076']
# random_int: ['2568', '9259']
# iban: ['GB97RUEU29517684305608', 'GB19UYJF39985318046640']
# past_date: ['2020-08-14', '2020-08-25']
# hex_color: ['#ded17a', '#2192b0']
# military_dpo: ['Unit 3171 Box 8346', 'Unit 9064 Box 3785']
# random_lowercase_letter: ['l', 'y']
# md5: ['ece6a99fb8d465f4579733d064e2e708', '6226fbb61ea0db6c6eda4a341a307179']
# uri_page: ['terms', 'privacy']
# company: ['Owen Inc', 'Miller, Welch and Davis']
# pylist: [['PCEBlXkDkntGQNxakqqM', 4698, datetime.datetime(1989, 1, 31, 9, 29, 23), 'hWbLaTsGNYJodoLSibhM', 'http://www.rojas.com/privacy.jsp', 'heUszSXzMvInwfoNaVAY', 3980, 'lDwQQGduAKqDrUGgkcLM', 6174], [6283, 'UQlngjXHVcUjmQeQsWIx', 'rvega@yahoo.com', Decimal('8508844801889.1'), 1941, 563, 'izlvhYOVSuJLrwxDxjUj', 'oOjCGowShpluszCCbPLI', -22.611, 'http://www.peterson-hamilton.info/blog/wp-content/homepage.jsp', 'http://thomas.com/main/wp-content/app/author.html']]
# random_number: ['20227110', '6']
# country: ['United States Minor Outlying Isl', 'Estonia']
# language_code: ['sa', 'kl']
# swift11: ['GLKSGBW93HZ', 'PYPKGBAQ0B5']
# company_email: ['kimberlysteele@norris.com', 'qday@savage.com']
# email: ['lisapeterson@frazier-murphy.org', 'carolyncook@gmail.com']
# suffix_female: ['MD', 'DDS']
# random_digit_not_null: ['5', '3']
# postalcode_in_state: ['36383', '90333']
# color: ['#c2f2f9', '#83f7b3']
# ipv4: ['217.83.9.80', '192.186.7.166']
# uri: ['http://www.davenport.biz/categor', 'https://dorsey.net/tag/tag/explo']
# random_digit_not_null_or_empty: ['6', '']
# latitude: ['-26.435208', '-74.0714825']
# http_method: ['POST', 'PUT']
# user_name: ['scottgross', 'cshields']
# windows_platform_token: ['Windows NT 6.1', 'Windows NT 6.0']
# date_this_year: ['2020-03-17', '2020-08-14']
# dsv: ['"Andrew Nunez","172 Kristen Skyw', '"Corey Ortiz","874 Nancy Locks\nW']
# pyint: ['7466', '5707']
# android_platform_token: ['Android 1.1', 'Android 3.2']
# iso8601: ['2018-12-08T07:18:16', '1985-11-30T12:02:29']
# localized_ean: ['1367156894808', '1195105506102']
# street_address: ['993 Alexandra Trace Apt. 903', '99060 Buck Road Suite 145']
# pystruct: ["(['http://www.webb.com/', -87787", "(['hbiZGlCsAOLNQhUnpsad', 691, '"]
# credit_card_number: ['3509901874490195', '340720138022340']
